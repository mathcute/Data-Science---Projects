# %% [markdown]
# <a href="https://colab.research.google.com/github/mathcute/Data-Science---Projects/blob/main/Projeto_4_An%C3%A1lise_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1. Qual é o valor do aluguel (diária) mais caro de cada região da base de dados da cidade de Nova York?

# %%
import pandas as pd
import plotly.express as px

data = pd.read_csv('/content/AB_NYC_2019[1].csv')

colunas = ['price', 'neighbourhood_group']
colunas_groupby = ['neighbourhood_group']

data_plot = data.loc[:, colunas].groupby(colunas_groupby).max().reset_index()

px.bar(data_plot, x = 'neighbourhood_group', y = 'price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3eb88c56-4a7f-46c3-a895-8f1b3abdc23f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3eb88c56-4a7f-46c3-a895-8f1b3abdc23f")) {                    Plotly.newPlot(                        "3eb88c56-4a7f-46c3-a895-8f1b3abdc23f",                        [{"alignmentgroup":"True","hovertemplate":"neighbourhood_group=%{x}\u003cbr\u003eprice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bronx","Brooklyn","Manhattan","Queens","Staten Island"],"xaxis":"x","y":[2500,10000,10000,10000,5000],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo", ...

# %% [markdown]
# ##2. Conseguimos saber onde estão localizados os imóveis com o valor do aluguel mais caro, na cidade de Nova York?

# %%
# Importando as bibliotecas
import pandas as pd
import plotly.express as px
import folium

# Carregando o conjunto de dados

data = pd.read_csv( '/content/AB_NYC_2019[1].csv' )

# Selecionando linhas e colunas

colunas = ['price', 'neighbourhood_group', 'latitude', 'longitude']
colunas_groupby = ['neighbourhood_group']

# Criando os segmentos

data_plot = data.loc[:, colunas].groupby(colunas_groupby).max().reset_index()

# Criando a área do mapa

f = folium.Figure( width='1024', height=768 )

# Desenhando o mapa

map = folium.Map(

location=[data_plot['latitude'].mean(),
data_plot['longitude'].mean()],
zoom_start=14,
control_scale=True

)
# Adicionando os pinos nos mapas

for index, location_info in data_plot.iterrows():

  folium.Marker( [location_info['latitude'],
  location_info['longitude']],
  popup=location_info['neighbourhood_group'] ).add_to( map )

# Mostrando o mapa
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fe216c6738b28c01ae0cad6659a65d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fe216c6738b28c01ae0cad6659a65d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fe216c6738b28c01ae0cad6659a65d7 = L.map(
#                 &quot;map_1fe216c6738b28c01ae0cad6659a65d7&quot;,
#                 {
#                     center: [40.794722, -73.86416],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1fe216c6738b28c01ae0cad6659a65d7);
#
#
#
#
#
#             var tile_layer_d6778e0ff69c779aca6d3842940c1327 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1fe216c6738b28c01ae0cad6659a65d7);
#
#
#             var marker_c7f1c02aa6a5f4ced9c07165a6ad5cc6 = L.marker(
#                 [40.91306, -73.78158],
#                 {}
#             ).addTo(map_1fe216c6738b28c01ae0cad6659a65d7);
#
#
#         var popup_711d903deb49c1f6b7fcac1b952a6222 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05d318cf8888ac175e9872629cb1a4ff = $(`&lt;div id=&quot;html_05d318cf8888ac175e9872629cb1a4ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_711d903deb49c1f6b7fcac1b952a6222.setContent(html_05d318cf8888ac175e9872629cb1a4ff);
#
#
#
#         marker_c7f1c02aa6a5f4ced9c07165a6ad5cc6.bindPopup(popup_711d903deb49c1f6b7fcac1b952a6222)
#         ;
#
#
#
#
#             var marker_5975d3d5317b65ff0b50c2e67c581603 = L.marker(
#                 [40.7389, -73.85676],
#                 {}
#             ).addTo(map_1fe216c6738b28c01ae0cad6659a65d7);
#
#
#         var popup_0ae2f10207d2b81a776a2cef132e19dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7cd383f51ee54a7d8e3da2815d15d3b = $(`&lt;div id=&quot;html_d7cd383f51ee54a7d8e3da2815d15d3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn&lt;/div&gt;`)[0];
#                 popup_0ae2f10207d2b81a776a2cef132e19dc.setContent(html_d7cd383f51ee54a7d8e3da2815d15d3b);
#
#
#
#         marker_5975d3d5317b65ff0b50c2e67c581603.bindPopup(popup_0ae2f10207d2b81a776a2cef132e19dc)
#         ;
#
#
#
#
#             var marker_63079f735b2d2d9c60298a975d86444f = L.marker(
#                 [40.87665, -73.90855],
#                 {}
#             ).addTo(map_1fe216c6738b28c01ae0cad6659a65d7);
#
#
#         var popup_0f88d3e58c3f9a4f75b2adb4a5a8da6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a7cc3e0cc8dd1bf3edba3ca04ab3eb3 = $(`&lt;div id=&quot;html_9a7cc3e0cc8dd1bf3edba3ca04ab3eb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#                 popup_0f88d3e58c3f9a4f75b2adb4a5a8da6e.setContent(html_9a7cc3e0cc8dd1bf3edba3ca04ab3eb3);
#
#
#
#         marker_63079f735b2d2d9c60298a975d86444f.bindPopup(popup_0f88d3e58c3f9a4f75b2adb4a5a8da6e)
#         ;
#
#
#
#
#             var marker_c8986bc2122da6b335fab78b1e3a771f = L.marker(
#                 [40.79721, -73.71299],
#                 {}
#             ).addTo(map_1fe216c6738b28c01ae0cad6659a65d7);
#
#
#         var popup_fbd15aa88d64580f580b5fb7a68eb6ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f096beee2c6fc27775c65ebc6b592f3 = $(`&lt;div id=&quot;html_7f096beee2c6fc27775c65ebc6b592f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queens&lt;/div&gt;`)[0];
#                 popup_fbd15aa88d64580f580b5fb7a68eb6ff.setContent(html_7f096beee2c6fc27775c65ebc6b592f3);
#
#
#
#         marker_c8986bc2122da6b335fab78b1e3a771f.bindPopup(popup_fbd15aa88d64580f580b5fb7a68eb6ff)
#         ;
#
#
#
#
#             var marker_b0956456f23f29ae7127b1907d0be745 = L.marker(
#                 [40.64779, -74.06092],
#                 {}
#             ).addTo(map_1fe216c6738b28c01ae0cad6659a65d7);
#
#
#         var popup_d962d098adba3f09db4ced3bbc85f47e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4f5f80f55c752eef45e1f9b9383ebd4 = $(`&lt;div id=&quot;html_f4f5f80f55c752eef45e1f9b9383ebd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Staten Island&lt;/div&gt;`)[0];
#                 popup_d962d098adba3f09db4ced3bbc85f47e.setContent(html_f4f5f80f55c752eef45e1f9b9383ebd4);
#
#
#
#         marker_b0956456f23f29ae7127b1907d0be745.bindPopup(popup_d962d098adba3f09db4ced3bbc85f47e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:

# %% [markdown]
# ##3. Conseguimos saber onde estão localizados os imóveis pelo seu tipo?

# %%
# Importando as bibliotecas
import pandas as pd
import plotly.express as px
import folium

# Carregando o arquivo
data = pd.read_csv( '/content/AB_NYC_2019[1].csv' )

# Selecionando linhas aleatoriamente e colunas
colunas = ['neighbourhood_group', 'room_type', 'latitude', 'longitude']
data_plot = data.loc[:, colunas].sample( 100 )

# Criando uma nova coluna chamada 'color'
data_plot.loc[:, 'color'] = 'NA'

# Selecionando as linhas do segmento
linhas_private_room = data_plot.loc[:, 'room_type'] == 'Private room'
linhas_entire_apt = data_plot.loc[:, 'room_type'] == 'Entire home/apt'
linhas_shared_room = data_plot.loc[:, 'room_type'] == 'Shared room'

# Colocando as cores para cada segmento
data_plot.loc[linhas_private_room, 'color'] = 'darkgreen'
data_plot.loc[linhas_entire_apt, 'color'] = 'darkred'
data_plot.loc[linhas_shared_room, 'color'] = 'purple'

# Criando a área do mapa
map = folium.Map()

# Adicionando os pins nos mapas
for index, location_info in data_plot.iterrows():

  folium.Marker(
  [location_info['latitude'], location_info['longitude']],
  popup=location_info[['neighbourhood_group', 'room_type']],
  icon=folium.Icon( color=location_info['color'] )
  ).add_to( map )

# Exibindo o mapa
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0921dc4003c1df8c2a789428b29d66cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0921dc4003c1df8c2a789428b29d66cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0921dc4003c1df8c2a789428b29d66cf = L.map(
#                 &quot;map_0921dc4003c1df8c2a789428b29d66cf&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ef75996419b94c5be5f5fc66b23f6ad = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0921dc4003c1df8c2a789428b29d66cf);
#
#
#             var marker_aa84692f79eb949f8eeae21d477f987d = L.marker(
#                 [40.82744, -73.94707],
#                 {}
#             ).addTo(map_0921dc4003c1df8c2a789428b29d66cf);
#
#
#             var icon_8c822e72487199fbe119749ed56fc43e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aa84692f79eb949f8eeae21d477f987d.setIcon(icon_8c822e72487199fbe119749ed56fc43e);
#
#
#         var popup_cf8ac8ae0a4d756a9dfa7586d20d9e61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_422adfb571f75d192d375fc5a93782f9 = $(`&lt;div id=&quot;html_422adfb571f75d192d375fc5a93782f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group       Manhattan room_type              Private room Name: 25479, dtype: object&lt;/div&gt;`)[0];
#                 popup_cf8ac8ae0a4d756a9dfa7586d20d9e61.setContent(html_422adfb571f75d192d375fc5a93782f9);
#
#
#
#         marker_aa84692f79eb949f8eeae21d477f987d.bindPopup(popup_cf8ac8ae0a4d756a9dfa7586d20d9e61)
#         ;
#
#
#
#
#             var marker_b64b82887df3e7df666171f5d0d0d4be = L.marker(
#                 [40.74305, -73.9007],
#                 {}
#             ).addTo(map_0921dc4003c1df8c2a789428b29d66cf);
#
#
#             var icon_09e962269e91c530fb627f9365315d3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b64b82887df3e7df666171f5d0d0d4be.setIcon(icon_09e962269e91c530fb627f9365315d3a);
#
#
#         var popup_3dc12938d6286f4a2609fbac62df962f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d64624e495343edc3bc9adbdd3d6e2b = $(`&lt;div id=&quot;html_0d64624e495343edc3bc9adbdd3d6e2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group             Queens room_type              Entire home/apt Name: 45843, dtype: object&lt;/div&gt;`)[0];
#                 popup_3dc12938d6286f4a2609fbac62df962f.setContent(html_0d64624e495343edc3bc9adbdd3d6e2b);
#
#
#
#         marker_b64b82887df3e7df666171f5d0d0d4be.bindPopup(popup_3dc12938d6286f4a2609fbac62df962f)
#         ;
#
#
#
#
#             var marker_0318ec616c53d17cffd5335b71a40b33 = L.marker(
#                 [40.77633, -73.97932],
#                 {}
#             ).addTo(map_0921dc4003c1df8c2a789428b29d66cf);
#
#
#             var icon_274ef92353397302c6040fbc4dc097ca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0318ec616c53d17cffd5335b71a40b33.setIcon(icon_274ef92353397302c6040fbc4dc097ca);
#
#
#         var popup_89e7dc9cb1150ef2004eecb85c5d3574 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c28f44569faa668f6d3685f08c85218 = $(`&lt;div id=&quot;html_0c28f44569faa668f6d3685f08c85218&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neighbourhood_group          Manhattan room_type              Entire home/apt Name: 12926, dtype: object&lt;/div&gt;`)[0];
#                 popup_89e7dc9cb1150ef2004eecb85c5d3574.setContent(html_0c28f44569faa668f6d3685f08c85218);
#
#
#
#         marker_0318ec616c53d17cffd5335b71a40b33.bindPopup(popup_89e7dc9cb1150ef2004eecb85c5d3574)
#         ;
#
#
#
#
#             var marker_3e6eca6e532ce8b1446f56dea92a49b7 = L.marker(
#                 [40.69048, -73.92193],
